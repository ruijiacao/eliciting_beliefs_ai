# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/experimental_notebooks/
# !pip install datasets
# !pip install transformers
# !pip install torch
# !pip install sklearn
# !pip install tqdm

# %%
# %load_ext autoreload
# %autoreload 2
import utils
import torch
import numpy as np
import all_classes
from tqdm import tqdm
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, AutoModelForMaskedLM, AutoModelForCausalLM, AutoModel
from sklearn.linear_model import LogisticRegression
import itertools
from huggingface_hub import login
token = "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"  # Your Hugging Face token
login(token=token)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 3 import utils
#       4 import torch
#       5 import numpy as np
#
# File ~/Documents/Ruijia/Research/eliciting_beliefs_llm/eliciting_beliefs_ai/experimental_notebooks/utils.py:2
#       1 # File containing useful functions
# ----> 2 import torch
#       3 import numpy as np
#       4 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ##### Load Dataset

# %%
#load datasets
dataset_name = "imdb"
data = load_dataset("imdb")["test"]
data = np.array(data)
data_testing = load_dataset("amazon_polarity")["test"]
data_testing = np.array(data_testing)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# unsupervised-00000-of-00001.parquet:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# README.md:   0%|          | 0.00/6.81k [00:00<?, ?B/s]
# train-00000-of-00004.parquet:   0%|          | 0.00/260M [00:00<?, ?B/s]
# train-00001-of-00004.parquet:   0%|          | 0.00/258M [00:00<?, ?B/s]
# train-00002-of-00004.parquet:   0%|          | 0.00/255M [00:00<?, ?B/s]
# train-00003-of-00004.parquet:   0%|          | 0.00/254M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/117M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/3600000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/400000 [00:00<?, ? examples/s]

# %% [markdown]
# ##### Load Model

# %%
# Here are a few different model options you can play around with:
model_name = "llama3.2"
# model_name = "llama3.3"

# the number of hidden dimensions of the model
hidden_size = 2048
num_layers = 16

cache_dir = None

if model_name == "llama3.2":
    model_type = "decoder"
    tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-1B-Instruct", cache_dir=cache_dir, token=True)
    model = AutoModel.from_pretrained("meta-llama/Llama-3.2-1B-Instruct", cache_dir=cache_dir, token=True)
    hidden_size = model.config.hidden_size
    num_layers = model.config.num_hidden_layers
else:
    print("Not implemented!")
# Out:
# tokenizer_config.json:   0%|          | 0.00/54.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/877 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]

# %%
# sample = np.random.choice(data, 2)
# print(sample.shape[0])
# print(sample[0])
# print(sample[0])
# print(sample[1])
# Out:
# 2

# %%
# test = "Is the sky blue? Answer: True"
# output = utils.get_decoder_hidden_states(model, tokenizer, test, layer = -1, token_pos = -1)
# output_2 = utils.get_decoder_hidden_states(model, tokenizer, test, layer = -1, token_pos = -2)
# print(output)
# print(output_2)

# %%
# let's create a simple 50/50 train split (the data is already randomized)
# n = len(y)
# neg_hs_train, neg_hs_test = neg_hs[:n//2], neg_hs[n//2:]
# pos_hs_train, pos_hs_test = pos_hs[:n//2], pos_hs[n//2:]
# y_train, y_test = y[:n//2], y[n//2:]

# # for simplicity we can just take the difference between positive and negative hidden states
# # (concatenating also works fine)
# x_train = neg_hs_train - pos_hs_train
# x_test = neg_hs_test - pos_hs_test

# lr = LogisticRegression(class_weight="balanced")
# lr.fit(x_train, y_train)
# print("Logistic regression accuracy: {}".format(lr.score(x_test, y_test)))

# ccs = all_classes.CE(neg_hs_train, pos_hs_train)
# ccs.repeated_train()

# # Evaluate
# ccs_acc = ccs.get_acc(neg_hs_test, pos_hs_test, y_test)
# print("CCS accuracy: {}".format(ccs_acc))
# print(ccs.get_credence(neg_hs_test, pos_hs_test))
# Out:
# Logistic regression accuracy: 0.26666666666666666
# CCS accuracy: 0.6

# %% [markdown]
# ## Aggregating probes from all layers

# %%
# aggregate a list of credences into one estimate using geometric mean
# def aggregate_gmean(credences):
#     k = np.shape(credences)[0]
#     result = np.power(np.prod(credences * (1 / (1 - credences))), 1 / k)
#     return 1 / (1 + result)

# %% [markdown]
# Get the hidden state representations from the specified layers

# %%
# num_example = 2
# data_sampled = np.random.choice(data, num_example)
# layer_idx = [1, 3, 5, 7, -1] # training 5 probes
# all_neg_hs, all_pos_hs, all_y = utils.get_hidden_states_aggregate(model, tokenizer, data, dataset_name, model_type, layer_idx, num_samples = num_example)

# %% [markdown]
# Get a list of probes for each specified layer

# %%
# probes = []
# probabilities = []
# pos_hs = [cur_pos_hs[0] for cur_pos_hs in all_pos_hs]
# pos_hs = np.stack(pos_hs)
# print(pos_hs.shape)
# for i in range(len(layer_idx)):
#     pos_hs = [cur_pos_hs[i] for cur_pos_hs in all_pos_hs]
#     neg_hs = [cur_neg_hs[i] for cur_neg_hs in all_neg_hs]
#     pos_hs = np.stack(pos_hs)
#     neg_hs = np.stack(neg_hs)
#     neg_hs_train, neg_hs_test = neg_hs[ : num_example // 2], neg_hs[num_example // 2 : ]
#     pos_hs_train, pos_hs_test = pos_hs[ : num_example // 2], pos_hs[num_example // 2 : ]
#     y_train, y_test = all_y[ : num_example // 2], all_y[ num_example // 2 : ]
#     credence = all_classes.CE(neg_hs_train, pos_hs_train)
#     credence.repeated_train()
#     # probes.append(credence.best_probe)
#     probabilities.append(credence.get_credence(neg_hs_test, pos_hs_test).detach().cpu().numpy())
# Out:
# (30, 2048)

# %% [markdown]
# Test accuracy by aggregating all the probes

# %%
# probabilities = np.array(probabilities)
# probabilities = np.reshape(probabilities, (len(layer_idx), num_example // 2))
# probs_agg = [aggregate_gmean(probabilities[:, j]) for j in range(num_example // 2)]
# probs_agg = np.array(probs_agg)
# predictions = (probs_agg < 0.5).astype(int)
# print(predictions)
# print(y_test)

# %%
# acc = (predictions == y_test).mean()
# acc = max(acc, 1 - acc)
# print("CCS accuracy by aggregating truth vectors: {}".format(acc))

# %% [markdown]
# ### Aggregating Multiple probes

# %% [markdown]
# #### Some helper functions

# %%
1def normalize(x, var_normalize = False):
    """
    Mean-normalizes the data x (of shape (n, d))
    If self.var_normalize, also divides by the standard deviation
    """
    normalized_x = x - x.mean(axis=0, keepdims=True)
    if var_normalize:
        normalized_x /= normalized_x.std(axis=0, keepdims=True)

    return normalized_x

def get_credence(probe, x0_test, x1_test, device = "cpu"):
    """
    Given a probe, compute credence for the current parameters on the given test inputs
    """
    x0 = torch.tensor(normalize(x0_test), dtype=torch.float, requires_grad=False, device=device)
    x1 = torch.tensor(normalize(x1_test), dtype=torch.float, requires_grad=False, device=device)
    with torch.no_grad():
        p0, p1 = probe(x0), probe(x1)
    avg_confidence = 0.5 * (p0 + (1 - p1))

    return avg_confidence

def get_random_samples(data_set, n):
    return np.random.choice(data_set, n)


def get_hidden_states_many_examples(model, tokenizer, data, dataset_name, model_type, params):
    """
    Given an encoder-decoder model, a list of data, computes the contrast hidden states on n random examples by probing the model according to the specified parameters (param = (layer_indices, token_positions, prompt_versions))
    Returns numpy arrays of shape (n, hidden_dim) for each candidate label, along with a boolean numpy array of shape (n,)
    with the ground truth labels

    This is deliberately simple so that it's easy to understand, rather than being optimized for efficiency
    """
    # setup
    model.eval()
    all_neg_hs, all_pos_hs, all_gt_labels = [], [], []
    layer, token_pos, prompt_version = params

    # loop
    for sample in data:
        if dataset_name == "imdb":
            text, true_label = sample["text"], sample["label"]
        else:
            text, true_label = sample["content"], sample["label"]


        # get hidden statls
        neg_hs = utils.get_hidden_states(model, tokenizer, format(prompt_version, text, 0), token_pos, layer, model_type=model_type)
        pos_hs = utils.get_hidden_states(model, tokenizer, format(prompt_version, text, 1), token_pos, layer, model_type=model_type)

        # collect
        all_neg_hs.append(neg_hs)
        all_pos_hs.append(pos_hs)
        all_gt_labels.append(true_label)

    all_neg_hs = np.stack(all_neg_hs)
    all_pos_hs = np.stack(all_pos_hs)
    all_gt_labels = np.stack(all_gt_labels)

    return all_neg_hs, all_pos_hs, all_gt_labels

# %% [markdown]
# ##### Functions for Aggregating Credences

# %%
# aggregate a list of credences into one estimate using geometric mean
def aggregate_gmean(credences):
    k = np.shape(credences)[0]
    result = np.power(np.prod(credences * (1 / (1 - credences))), 1 / k)
    return 1 / (1 + result)

# (To-DO) aggregragate a list of credences using weighted geometric mean
def aggregate_gmean_weighted(credences, weights):
    pass

# %% [markdown]
# Functions for Formating Prompts

# %%
# Functions for formating contrasting pairs
def format_1(text, label):
    """
    Given an imdb example ("text") and corresponding label (0 for negative, or 1 for positive),
    returns a zero-shot prompt for that example (which includes that label as the answer).

    (This is just one example of a simple, manually created prompt.)
    """
    return "The following review expresses a " + ["negative", "positive"][label] + " sentiment:\n" + text

def format_2(text, label):
    """
    Given an imdb example ("text") and corresponding label (0 for negative, or 1 for positive),
    returns an alternative zero-shot prompt for that example (which includes that label as the answer).

    (This is just one example of a simple, manually created prompt.)
    """
    return "The sentiment of " + text + " is negative? " + "Answer: " + ["negative", "positive"][label]

def format_3(text, label):
    """
    Given an imdb example ("text") and corresponding label (0 for negative, or 1 for positive),
    returns a zero-shot prompt for that example (which includes that label as the answer).

    (This is just one example of a simple, manually created prompt.)
    """
    return "Consider the sentiment of the following review:\n" + text + "\nDoes the above movie review express a " + ["negative", "positive"][label] + " sentiment? " + "Answer: " + "Yes"

def format(version, text, label):
    prompt_form = {"version_1": format_1, "version_2": format_2, "version_3": format_3}[version]
    return prompt_form(text, label)

# %% [markdown]
# ##### Constructing CCS Pairs

# %%
# hyper-parameters
num_example = 100
layer_idices = [1, 3, 5, 7, -1]
token_positions = [-2, -1]
prompt_versions = ["version_1", "version_2", "version_3"]
data_sampled = get_random_samples(data, num_example)
test_date_sampled = get_random_samples(data_testing, num_example)

# %%
hidden_states_all = {}
hidden_states_all_test = {} # hidden states for testing
for (token_pos, layer_idx, version) in itertools.product(token_positions, layer_idices, prompt_versions):
    neg_hs_test, pos_hs_test, y_test = get_hidden_states_many_examples(model, tokenizer, test_date_sampled, "amazon_polarity", model_type, (token_pos, layer_idx, version))
    neg_hs, pos_hs, y = get_hidden_states_many_examples(model, tokenizer, data_sampled, dataset_name, model_type, (token_pos, layer_idx, version))
    hidden_states_all[(token_pos, layer_idx, version)] = (neg_hs, pos_hs, y)
    hidden_states_all_test[(token_pos, layer_idx, version)] = (neg_hs_test, pos_hs_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-a882ad5fb701> in <cell line: 0>()
#       3 for (token_pos, layer_idx, version) in itertools.product(token_positions, layer_idices, prompt_versions):
#       4     neg_hs_test, pos_hs_test, y_test = get_hidden_states_many_examples(model, tokenizer, test_date_sampled, "amazon_polarity", model_type, (token_pos, layer_idx, version))
# ----> 5     neg_hs, pos_hs, y = get_hidden_states_many_examples(model, tokenizer, data_sampled, dataset_name, model_type, (token_pos, layer_idx, version))
#       6     hidden_states_all[(token_pos, layer_idx, version)] = (neg_hs, pos_hs, y)
#       7     hidden_states_all_test[(token_pos, layer_idx, version)] = (neg_hs_test, pos_hs_test, y_test)
#
# <ipython-input-8-4447240833f5> in get_hidden_states_many_examples(model, tokenizer, data, dataset_name, model_type, params)
#      48
#      49         # get hidden statls
# ---> 50         neg_hs = utils.get_hidden_states(model, tokenizer, format(prompt_version, text, 0), token_pos, layer, model_type=model_type)
#      51         pos_hs = utils.get_hidden_states(model, tokenizer, format(prompt_version, text, 1), token_pos, layer, model_type=model_type)
#      52
#
# /content/drive/MyDrive/Colab_Notebooks/experimental_notebooks/utils.py in get_hidden_states(model, tokenizer, input_text, token_pos, layer, model_type)
#      69           "decoder": get_decoder_hidden_states}[model_type]
#      70
# ---> 71     return fn(model, tokenizer, input_text, token_pos, layer)
#      72
#      73 # Functions for formating contrasting pairs
#
# /content/drive/MyDrive/Colab_Notebooks/experimental_notebooks/utils.py in get_decoder_hidden_states(model, tokenizer, input_text, token_pos, layer)
#      57     # forward pass
#      58     with torch.no_grad():
# ---> 59         output = model(input_ids, output_hidden_states=True)
#      60
#      61     # probe the specified layer and token position
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     590                 )
#     591             else:
# --> 592                 layer_outputs = decoder_layer(
#     593                     hidden_states,
#     594                     attention_mask=causal_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     349         residual = hidden_states
#     350         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 351         hidden_states = self.mlp(hidden_states)
#     352         hidden_states = residual + hidden_states
#     353
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, x)
#     187
#     188     def forward(self, x):
# --> 189         down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#     190         return down_proj
#     191
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Training Probes

# %%
print(hidden_states_all[(-2, 1, "version_1")])
print(hidden_states_all[(-2, 1, "version_2")])
# Out:
# (array([[ 0.1521416 , -0.12457201, -0.13509154, ..., -0.59588444,
#          0.07217482, -0.37062675],
#        [ 0.1521416 , -0.12457201, -0.13509154, ..., -0.59588444,
#          0.07217482, -0.37062675]], dtype=float32), array([[ 0.1521416 , -0.12457201, -0.13509154, ..., -0.59588444,
#          0.07217482, -0.37062675],
#        [ 0.1521416 , -0.12457201, -0.13509154, ..., -0.59588444,
#          0.07217482, -0.37062675]], dtype=float32), array([0, 1]))
# (array([[-0.20350677, -0.13989104,  0.3945287 , ..., -0.17272857,
#          0.11170533, -0.22297384],
#        [-0.20350677, -0.13989104,  0.3945287 , ..., -0.17272857,
#          0.11170533, -0.22297384]], dtype=float32), array([[-0.20350677, -0.13989104,  0.3945287 , ..., -0.17272857,
#          0.11170533, -0.22297384],
#        [-0.20350677, -0.13989104,  0.3945287 , ..., -0.17272857,
#          0.11170533, -0.22297384]], dtype=float32), array([0, 1]))

# %%
probes = {} # a python dictionary of best probes accordng to the specified testing hyperparameters
probabilities = {} # a python dictionary of credences according to
log_reg = {}
for (token_pos, layer_idx, version) in itertools.product(token_positions, layer_idices, prompt_versions):
    neg_hs, pos_hs, all_y = hidden_states_all[(token_pos, layer_idx, version)]
    neg_hs_test, pos_hs_test, all_y_test = hidden_states_all_test[(token_pos, layer_idx, version)]
    neg_hs_train, pos_hs_train = neg_hs, pos_hs
    y_train, y_test = all_y, all_y_test
    # train probe
    credence_estimator = all_classes.CE(neg_hs_train, pos_hs_train)
    credence_estimator.repeated_train()
    cur_best_probe = credence_estimator.get_best_probe()
    probes[(token_pos, layer_idx, version)] = cur_best_probe
    probabilities[(token_pos, layer_idx, version)] = credence_estimator.get_credence(neg_hs_test, pos_hs_test).detach().cpu().numpy()
    # compute logistic regression

    # x_train = neg_hs_train - pos_hs_train
    # x_test = neg_hs_test - pos_hs_test
    # lr = LogisticRegression(class_weight="balanced")
    # lr.fit(x_train, y_train)
    # log_reg[(token_pos, layer_idx, version)] = lr.score(x_test, y_test)

# %%
# print(probabilities)

# %% [markdown]
# ##### Testing Accuracies of the Probes

# %%
# list of aggregated credences
credences_aggregated = []
for i in range(num_example // 2):
    # list of all credences of example i
    all_estimates = [credences[i] for credences in probabilities.values()]
    credences_aggregated.append(aggregate_gmean(np.array(all_estimates)))

# list of true labels from the test set (the training examples are the same in training the probes)
_, _, all_y = hidden_states_all_test[(-2, 1, "version_1")]
credences_aggregated = np.array(credences_aggregated)
y_test = all_y
predictions = (credences_aggregated < 0.5).astype(int)
acc = (predictions == y_test).mean()
acc = max(acc, 1 - acc)
print(acc)
# Out:
# 1.0

# %% [markdown]
# ##### Logistic Regression
